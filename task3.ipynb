# %%
a=int(input("enter first number"))
b=int(input("enter second number"))
c=a*b
print("multiplication of the two no is",c)
# multiplication cammand
# Out:
# enter first number558
# enter second number465
# multiplication of the two no is 259470
